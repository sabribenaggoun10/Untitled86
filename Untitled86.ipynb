# %% [markdown]
# <a href="https://colab.research.google.com/github/sabribenaggoun10/Untitled86/blob/main/Untitled86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "5"
print(type(a))
# Out:
# <class 'str'>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("netflix_titles.csv")

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb           Unkown
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.describe(include='all')
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# top      s8807  Movie  Zubaan  Rajiv Chilaka  David Attenborough
# freq         1   6131       1             19                  19
# mean       NaN    NaN     NaN            NaN                 NaN
# std        NaN    NaN     NaN            NaN                 NaN
# min        NaN    NaN     NaN            NaN                 NaN
# 25%        NaN    NaN     NaN            NaN                 NaN
# 50%        NaN    NaN     NaN            NaN                 NaN
# 75%        NaN    NaN     NaN            NaN                 NaN
# max        NaN    NaN     NaN            NaN                 NaN
#
#               country       date_added  release_year rating  duration  \
# count            7976             8797   8807.000000   8803      8804
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.columns = df.columns.str.strip().str.lower().str.replace('*', '_')
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # **Drop**

# %%
df.shape
# Out:
# (8807, 12)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (5332, 12)

# %%
df.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director          0
# cast            825
# country         831
# date_added       10
# release_year      0
# rating            4
# duration          3
# listed_in         0
# description       0
# dtype: int64

# %% [markdown]
# ## **Filing**

# %%
df['director'].fillna(value="Unkown", inplace=True)
# Out:
# /tmp/ipykernel_6659/2601164212.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna(value="Unkown", inplace=True)

# %% [markdown]
# # **other code**

# %%
df.sample(5)
# Out:
#      show_id   type                              title  \
# 8377   s8378  Movie                  The King's Speech
# 8385   s8386  Movie                      The Last Face
# 7005   s7006  Movie                            Hot Rod
# 1904   s1905  Movie  Carlos Almaraz: Playing with Fire
# 7931   s7932  Movie                    Sanai Choughade
#
#                                     director  \
# 8377                              Tom Hooper
# 8385                               Sean Penn
# 7005                          Akiva Schaffer
# 1904  Elsa Flores Almaraz, Richard J Montoya
# 7931                            Rajeev Patil
#
#                                                    cast  \
# 8377  Colin Firth, Geoffrey Rush, Helena Bonham Cart...
# 8385  Javier Bardem, Charlize Theron, Adèle Exarchop...
# 7005  Andy Samberg, Jorma Taccone, Bill Hader, Danny...
# 1904               Edward James Olmos, Zach De La Rocha
# 7931  Shreyas Talpade, Subodh Bhave, Sai Tamhankar, ...
#
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.shape
# Out:
# (5332, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5332 entries, 7 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   object
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 541.5+ KB

# %%
df['country']
# Out:
# 7       United States, Ghana, Burkina Faso, United Kin...
# 8                                          United Kingdom
# 9                                           United States
# 12                                Germany, Czech Republic
# 24                                                  India
#                               ...
# 8801                         United Arab Emirates, Jordan
# 8802                                        United States
# 8804                                        United States
# 8805                                        United States
# 8806                                                India
# Name: country, Length: 5332, dtype: object

# %%
df[['country',"release_year"]]
# Out:
#                                                 country  release_year
# 7     United States, Ghana, Burkina Faso, United Kin...          1993
# 8                                        United Kingdom          2021
# 9                                         United States          2021
# 12                              Germany, Czech Republic          2021
# 24                                                India          1998
# ...                                                 ...           ...
# 8801                       United Arab Emirates, Jordan          2015
# 8802                                      United States          2007
# 8804                                      United States          2009
# 8805                                      United States          2006
# 8806                                              India          2015
#
# [5332 rows x 2 columns]

# %%
df[
  df['type'] == "Movie"
]
# Out:
#      show_id   type         title             director  \
# 7         s8  Movie       Sankofa         Haile Gerima
# 9        s10  Movie  The Starling       Theodore Melfi
# 12       s13  Movie  Je Suis Karl  Christian Schwochow
# 24       s25  Movie         Jeans           S. Shankar
# 27       s28  Movie     Grown Ups         Dennis Dugan
# ...      ...    ...           ...                  ...
# 8801   s8802  Movie       Zinzana      Majid Al Ansari
# 8802   s8803  Movie        Zodiac        David Fincher
# 8804   s8805  Movie    Zombieland      Ruben Fleischer
# 8805   s8806  Movie          Zoom         Peter Hewitt
# 8806   s8807  Movie        Zubaan          Mozez Singh
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %%
# !pip install matplotlib
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 362, in run
#     resolver = self.make_resolver(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 177, in make_resolver
#     return pip._internal.resolution.resolvelib.resolver.Resolver(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/resolution/resolvelib/resolver.py", line 58, in __init__
#     self.factory = Factory(
# ...

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.linspace(0, 5, 200)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine wave")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(3,3))
ax.plot(x,y)
ax.set_title("Sin trying")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.grid(True, alpha = 0.8)
ax.legend()
plt.show()
# Out:
# /tmp/ipykernel_6659/3349133524.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
x = np.arange(0, 20)
y1 = x + np.random.normal(0, 2, size=len(x))
y2 = 0.5 * x + np.random.normal(0, 2, size=len(x))

fig, ax = plt.subplots(figsize=(7, 4))
ax.plot(x, y1, marker="o", linewidth=2, label="series A")
ax.plot(x, y2, marker="s", linewidth=2, label="series B")
ax.set(title="Line plot", xlabel="time", ylabel="value")
ax.legend()
ax.grid(True, alpha=0.3)
plt.show()

# %%
fig, ax = plt.subplot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6659/3516328077.py in <cell line: 0>()
# ----> 1 fig, ax = plt.subplot()
#
# TypeError: cannot unpack non-iterable Axes object

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3], [4,5,6])
plt.title("Test Plot Method")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
import matplotlib.pyplot as plt


fig, ax = plt.subplots(figsize=(3,3))
ax.plot([1,2,3], [4,5,6])
ax.set_title("Test Plot Method")
ax.set_xlabel("X")
ax.set_ylabel("Y")


fig1, ax1 = plt.subplots(figsize=(3,3))
ax1.plot([1,2,3], [6,5,4])
ax1.set_title("Test Plot Method")
ax1.set_xlabel("X1")
ax1.set_ylabel("Y1")
print(fig.axes)

plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3], [2,4,1], color="C2", linewidth=1, marker="x", linestyle="--")
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter([1,2,3],[5,1,2], alpha=0.5, s=30)
plt.show()

# %%
fig, ax = plt.subplots()
ax.bar(["A","B","C"],[5,1,2])
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(["A","B","C"],[5,1,2])
plt.show()

# %%
fig, ax = plt.subplots()
ax.hist([1,1,2,2,2,3], bins=3, edgecolor="white")
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter([1,2,3],[5,1,2], alpha=0.5, s=30,label="Dot")
ax.legend()
ax.set_title("This is a title for the ax")
ax.set_ylabel("ylabel name")
ax.set_xlabel("xlabel name")
ax.grid(True, alpha=0.5)
ax.set_xlim(0,5)
ax.set_ylim(0,7)
ax.tick_params(axis="x",rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
fig, axs = subplots(2, 2, figsize=(10, 6))

axs[0,0].plot([1,2,3], [1,4,2])
axs[0,0].set_title("Plot 1")

axs[0,1].bar(["A","B"], [5,2])
axs[0,1].set_title("Plot 2")

axs[1,0].hist([1,2,2,3,3,3], bins=3)
axs[1,0].set_title("Plot 3")

axs[1,1].scatter([1,2,3], [3,1,2])
axs[1,1].set_title("Plot 4")

fig.tight_layout()
fig.savefig("test")
plt.show()

# %%
import pandas as pd
df = pd.read_csv("/content/netflix_titles.csv")

# %%
df.columns

# %%
df.head(2)

# %%
print("="*30)
print("netflix_titles: Data Report")
print("="*30)
print()
print('--Basic KPIs--')
print(f"Movies: {(df['type']=="Movie").sum()}")
print(f"TV Show: {(df['type']=="TV Show").sum()}")
print(f"Total titles: {len(df)}")
print(f"DataShape: {df.shape[1]}, {df.shape[0]}")
print()
print(df["type"].value_counts())
print()
print()

# %%
def make_bar(value, max_value, width=30):
    bar_length = int(value[1]/max_value*width)
    if bar_length == 0:
        bar_length = 1
    return "#"*bar_length

def print_bar_chart(data,width=30,display=True):
    max_value = -1
    max_len = 0
    for _, v in data:
        if(type(_) is str):
            if len(_.strip())> max_len:
                max_len = len(_)
        if v > max_value:
            max_value =  v
    s = ""
    for element in data:
        bar = make_bar(element,max_value,width)
        if type(element[0]) is str:
            if display:
                print(f"{element[0]:>{max_len}}| {bar} {element[1]}")
            s+=f"{element[0]:>{max_len}}| {bar} {element[1]}\n"
        else:
            if display:
                print(f"{element[0]}| {bar} {element[1]}")
            s+=f"{element[0]}| {bar} {element[1]}\n"
    return s

# %%
import matplotlib.pyplot as plt
per_year = df.loc[df["release_year"]>= 2010, "release_year"].value_counts().sort_index(ascending=False)
fig, axs = plt.subplots(figsize=(4,5))
axs.barh(per_year.index.astype(str),per_year.values)

axs.set_title("Titles Per Year")
axs.set_ylabel("Year")
axs.set_xlabel("Number of titles")
axs.grid()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the pie chart
sizes = [35, 25, 25, 15]
labels = ["Apples", "Bananas", "Cherries", "Dates"]

# Create the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)


# Ensure the chart is a perfect circle
plt.axis('equal')

# Add a title
plt.title('Fruit Preferences')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the visible half (e.g., two categories)
sizes = [30, 70]
labels = ['Category A', 'Category B']
colors = ['#ff9999', '#66b2ff']

# Add a dummy data point for the hidden half (sum of visible data)
# The sum of all values must represent a full circle.
total_sum = sum(sizes)
hidden_size = total_sum
sizes_full = sizes + [hidden_size]
# Add an empty label for the hidden part
labels_full = labels + ['']

# Create the plot
fig, ax = plt.subplots()
ax.pie(sizes_full,
       labels=labels_full,
       colors=colors + ['white'], # Use white color for the hidden part
       startangle=180,           # Start angle at 180 degrees (bottom of the circle)
       counterclock=False,       # Plot slices clockwise
       wedgeprops={'linewidth': 1, 'edgecolor': 'white'}) # Optional: customize wedge appearance

# Ensure the plot is a circle
ax.axis('equal')

# Adjust the y-axis limit to show only the top half
ax.set_ylim(0, 1.1) # Adjust the upper limit as needed for better spacing

plt.title('Half Pie Chart Example')
plt.show()
